# %% [markdown]
# # Vertical Chat
# A sample how to build a chat for small business using:
#
# * GPT 35
# * Panel
# * OpenAI
#
#
# This is just a simple sample to start to understand how the OpenAI API works, and how to create Prompts. It Is really far from beign a complete solution.
# We are going to introduce some interesting points:
#
# * The roles in a conversation.
# * How is the conversations’ memory preserved?
#
# Deeper explanations in the article: [Create Your First Chatbot Using GPT 3.5, OpenAI, Python and Panel.](https://medium.com/towards-artificial-intelligence/create-your-first-chatbot-using-gpt-3-5-openai-python-and-panel-7ec180b9d7f2)

# %%
! pip install jupyter_bokeh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 38.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
#if you need an API Key from OpenAI
#https://platform.openai.com/account/api-keys

from openai import OpenAI
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

def continue_conversation(messages, temperature=0):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=temperature,
    )
    #print(str(response.choices[0].message["content"]))
    return response.choices[0].message.content

# %%
def add_prompts_conversation(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''

    #Append to the context the User prompt.
    context.append({'role':'user', 'content':f"{prompt}"})

    #Get the response.
    response = continue_conversation(context)

    #Add the response to the context.
    context.append({'role':'assistant', 'content':f"{response}"})

    #Update the panels to show the conversation.
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
#Creating the prompt
#read and understand it.
import panel as pn  # GUI

context = [ {'role':'system', 'content':"""
Act as an OrderBot, you work collecting orders in a delivery only fast food restaurant called
My Dear Frankfurt. \
First welcome the customer, in a very friendly way, then collects the order. \
You wait to collect the entire order, beverages included \
then summarize it and check for a final \
time if everything is ok or the customer wants to add anything else. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very friendly style. \
The menu includes \
burger  12.95, 10.00, 7.00 \
frankfurt   10.95, 9.25, 6.50 \
sandwich   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
martra sausage 3.00 \
canadian bacon 3.50 \
romesco sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
vichy catalan 5.00 \
"""} ]

#Creating the panel.
pn.extension()
#pn.extension(comms='ipywidgets', design="material")

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b19c339b-5aef-4a31-a03e-6185db19236f'>
#   <div id="bb4be074-563e-4cc6-905b-6a19246078a2" data-root-id="b19c339b-5aef-4a31-a03e-6185db19236f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
#Creating the panel.
pn.extension()
#pn.extension(comms='ipywidgets', design="material")

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a1fc1f1b-47cb-489c-a787-196b7e9a8335'>
#   <div id="f99423cb-9f3d-49eb-a637-7290b32b458e" data-root-id="a1fc1f1b-47cb-489c-a787-196b7e9a8335" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
context = [ {'role':'system', 'content':"""
Act as an OrderBot, you work collecting orders for an online florist shop called
I Bloom. \
First welcome the customer, in a very friendly parfumed way, then collects the order. \
You wait to collect the entire order, types of bouquets, arragments, any add-ons, \
or needed delivery, then summarize it and check for a final \
time if everything is ok or the customer wants to add anything else. \
Finally you collect the payment. You check if the payement is correct. \
If not, you inform again the client about the value of the order. \
Make sure to clarify all options in the menu. \
You respond in a short, very friendly and parfumed style. \

The Flower Order Menu includes \

*Bouquets
Classic Rose Bouquet – €35 \
Seasonal Mixed Bouquet – €28 \
Sunflower Joy – €22 \
Elegant Lily Arrangement – €32 \

*Arrangements
Table Centerpiece – €40 \
Orchid Arrangement – €55 \
Wildflower Vase – €30 \

*Add‑Ons
Greeting card – €3 \
Vase upgrade – €8 \
Chocolates – €10 \
Ribbon wrap – €2 \

* Delivery Options \
Same‑day delivery – €7 \
Scheduled delivery – €5 \

"""} ]

#Creating the panel.
pn.extension()
#pn.extension(comms='ipywidgets', design="material")

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2e44f9e6-2b29-419c-8d08-a4f248b7752c'>
#   <div id="c06cd565-e5c0-4532-ac08-d22482e6142c" data-root-id="2e44f9e6-2b29-419c-8d08-a4f248b7752c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
context = [ {'role':'system', 'content':"""
Act as an OrderBot, you work collecting orders for a Hotel Room‑Service in the \
hotel Hotel Mama. First welcome the customer, in a very friendly fresh way, then \
collects the order. \
You wait to collect the entire order, types of food, possible drinks, \
always include the delivery costs (take care to explictly inform the customer \
about these costs). Then summarize it and check for a final \
time if everything is ok or the customer wants to add anything else. \
Finally you wait to collect the payment. You check if the payment is correct. \
If not, you inform again the client about the value of the order. \
Make sure to clarify all options from the menu. \
You respond in a short, very energetic style. \

The Hotel Room‑Service Menu includes \

* Breakfast (06:00–11:00) \
Continental Breakfast – €14 \
Croissant, bread roll, butter, jam, fruit, juice \
American Breakfast – €18 \
Eggs any style, bacon, toast, hash browns \
Avocado Toast – €12 \
Pancakes with Maple Syrup – €11 \

* All‑Day Dining (11:00–23:00) \
Club Sandwich + Fries – €16 \
Cheeseburger + Fries – €17 \
Caesar Salad – €13 \
Margherita Pizza – €15 \
Grilled Salmon with Vegetables – €22 \

* Light Bites \
Tomato Soup – €8 \
Mixed Green Salad – €9 \
Fruit Plate – €7 \

* Desserts \
Chocolate Lava Cake – €9 \
Cheesecake – €8 \
Ice Cream (2 scoops) – €6 \

* Drinks \
Soft Drinks – €3 \
Fresh Juice – €5 \
Coffee / Tea – €4 \
House Wine (Glass) – €7 \
Sparkling Water – €3 \

* Delivery Fee \
Room Delivery – €3

"""} ]

#Creating the panel.
pn.extension()
#pn.extension(comms='ipywidgets', design="material")

panels = []

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True),
)

dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6e6b2fe8-ef8f-45fd-b9eb-1a27a4f234e6'>
#   <div id="c0f6e706-e0b6-4452-b85f-c6a845442d77" data-root-id="6e6b2fe8-ef8f-45fd-b9eb-1a27a4f234e6" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# Conclusions:
# - In the initial order bot example, I ordered food worth $15.95, I offered to pay $15 cash, and the food was delivered to me. I want this in real life :).
# - The model correctly reacted in answering that alcohol was not served to minors.
# - OrderBot for flowers: there are several remarks: 1. delivery option was part of the menu, but the address of delivery was not requested by the Bot, 2. the Bot did not wait for the payment, instead offered to close the order before me telling how much I want to pay, 3. I payed in 2 steps, as I "forgot" to pay the complete sum in one step, this time the Bot verified the sum that I offered vs the worth of the order, but this time the Bot did not offer the rest back.
# - OrderBot Room Service: the delivery costs were not included in the calculation, as I thought they will be. The prompt must the detailed even more explicit for this step to be performed correctly.
